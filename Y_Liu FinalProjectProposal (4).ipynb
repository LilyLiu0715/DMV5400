# %% [markdown]
# # DAV 5400 Final Project Proposal

# %% [markdown]
# <font color=black size=5>Introduction</font>
#
#
# Economic freedom is a benefit to the money growth in the current global market, but someone would argue that economics is not good for the sound money and the government control should be enhanced to adjust the economic market. This is a hot topic especially in developing countries like China.

# %% [markdown]
# <font color=black size=5>Research Question</font>
#
# I would like to use the data to see which option is right and which factor can help money growth in the current global economy.
#
# If the data improve that economic freedom is related to money growth and too much government control harmed the sound money. I think this would be a reference when the government or organization wants to make policies on economic freedom. Also, I would take a deep look to research the two factors: the legal system and property rights, regulation. I presume the two attributes are correlated to the sound money. This would provide a detailed suggestion to the governments and organizations on which aspects that they might want to focus on.

# %% [markdown]
# <font color=black size=5>Data to be used</font>
#
# The data come from https://github.com/awesomedata/awesome-public-datasets#economics and https://www.fraserinstitute.org/studies/economic-freedom.
#
# ![python1.png](attachment:python1.png)
#
#
# Data from this source will be downloaded and convert as CSV file. https://github.com/LilyLiu0715/DMV5400/blob/master/efw-2019-final%20project.csv

# %% [markdown]
# <font color=black size=5>Approach</font>
#
# I will be storing it in the SQL database. The linear regression will be used the prove the relationship between economic freedom and sound money, sound money, and legal system rights, sound money and regulation. I will attempt to construct line plots that will show the correlation between these factors.
